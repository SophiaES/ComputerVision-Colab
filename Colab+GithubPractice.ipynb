# %% [markdown]
# <a href="https://colab.research.google.com/github/SophiaES/ComputerVision-Colab/blob/main/Colab%2BGithubPractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Colab과 Github 연동하기
# Let's learn how to use Colab and Github together:)

# %%
print("Hello Colab and Github")
# Out:
# Hello Colab and Github
